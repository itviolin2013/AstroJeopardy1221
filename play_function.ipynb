# %%
import numpy as np

categories = ["exoplanets", "blackholes", "galaxies", "stars", "solar system"]
point_values = ["100", "200", "300", "400", "500"]

def play():
    category = input("Enter your catagory: exoplanets, blackholes, galaxies, stars, solar system")

    if category in categories:
        point_value = input("select point value: 100, 200, 300, 400, 500")
    else:
        category =input("Please select a valid category: exoplanets, blackholes, galaxies, stars, solar system")

        if point_value in point_values:
            print(f"You have selected the {category} category for {point_value} points.")





play()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[16], line 21
#      14         if point_value in point_values:
#      15             print(f"You have selected the {category} category for {point_value} points.")
# ---> 21 play()
#
# Cell In[16], line 14, in play()
#      11 else:
#      12     category =input("Please select a valid category: exoplanets, blackholes, galaxies, stars, solar system")
# ---> 14     if point_value in point_values:
#      15         print(f"You have selected the {category} category for {point_value} points.")
#
# UnboundLocalError: cannot access local variable 'point_value' where it is not associated with a value

# %%
category = input("Enter your catagory:")
 if category == "exoplanets":
        print("select point value: 100, 200, 300, 400, 500")
        point_value = input()
        if point_value == "100":
